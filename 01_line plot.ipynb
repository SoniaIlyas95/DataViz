# %% [markdown]
# # Import libraries
# - seaborn
#
# - matplotlib
#
# seaborn automatically install these libraries(to install write "pip install seaborn" on vs code terminal)
# - numpy
#
# - pandas
#
# - scipy
#
# - matplotlib

# %%
# step 1 import libraries
import seaborn as sns
import matplotlib.pyplot as plt


# step 2 load data set/or import your own data
flower=sns.load_dataset("iris")
flower
# step 3 draw a line plot
#sns.countplot(x="sex", y="" data=flower)
#plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# step 1 import libraries
import seaborn as sns
import matplotlib.pyplot as plt


# step 2 load data set/or import your own data
flower=sns.load_dataset("iris")
flower
# step 3 draw a line plot[line plot always form between two numeric variable]
sns.lineplot(x="sepal_width", y="sepal_length", data=flower)
plt.show()

# %% [markdown]
# ## Adding titles

# %%
# step 1 import libraries
import seaborn as sns
import matplotlib.pyplot as plt


# step 2 load data set/or import your own data
flower=sns.load_dataset("iris")
flower
# step 3 draw a line plot[line plot always form between two numeric variable]
sns.lineplot(x="sepal_width", y="sepal_length", data=flower)
plt.title("plot between sepal_length and sepal_width")
plt.show()

# %% [markdown]
# ## Adding limits

# %%
# step 1 import libraries
import seaborn as sns
import matplotlib.pyplot as plt


# step 2 load data set/or import your own data
flower=sns.load_dataset("iris")
flower
# step 3 draw a line plot[line plot always form between two numeric variable]
sns.lineplot(x="sepal_width", y="sepal_length", data=flower)
plt.title("plot between sepal_length and sepal_width")
plt.xlim(3)
plt.ylim(2)
plt.show()

# %% [markdown]
# ## Adding style
# - dark
#
# - whitegrid
#
# - white
#
# - ticks

# %%
# step 1 import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# step 2 load data set/or import your own data
flower=sns.load_dataset("iris")
flower
# step 3 draw a line plot[line plot always form between two numeric variable]
sns.lineplot(x="sepal_width", y="sepal_length", data=flower)
plt.title("plot between sepal_length and sepal_width")
sns.set_style("dark")
sns.set_style(style=None, rc=None)
plt.show()

# %%
# step 1 import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# step 2 load data set/or import your own data
flower=sns.load_dataset("iris")
flower
# step 3 draw a line plot[line plot always form between two numeric variable]
sns.lineplot(x="sepal_width", y="sepal_length", data=flower)
plt.title("plot between sepal_length and sepal_width")
sns.set_style("whitegrid")
plt.show()

# %%
# step 1 import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# step 2 load data set/or import your own data
flower=sns.load_dataset("iris")
flower
# step 3 draw a line plot[line plot always form between two numeric variable]
sns.lineplot(x="sepal_width", y="sepal_length", data=flower)
plt.title("plot between sepal_length and sepal_width")
plt.style.use('dark_background')
plt.show()

# %% [markdown]
# ## Change figure size

# %%
# step 1 import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# step 2 load data set/or import your own data
flower=sns.load_dataset("iris")
flower
#change figure
plt.figure(figsize=(4,2))
# step 3 draw a line plot[line plot always form between two numeric variable]
sns.lineplot(x="sepal_width", y="sepal_length", data=flower)
plt.title("plot between sepal_length and sepal_width")
plt.show()
